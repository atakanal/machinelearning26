# %% [markdown]
# # naiveBayes
#
#
# Amaç, Naive Bayes yaklaşımını sadece kütüphane çağrısı olarak değil; veri dağılımları, olasılık hesapları ve sınıflandırma mantığı ile birlikte göstermektir.

# %% [markdown]
# ## 1. Teorik Giriş
#
# Naive Bayes, Bayes teoremini kullanarak sınıf olasılıklarını hesaplayan bir sınıflandırma yöntemidir.
# Temel varsayımı, özelliklerin sınıf koşulunda birbirinden bağımsız olduğudur.

# %%
import numpy as np
import pandas as pd

# TODO:
# Veri setini yukle ve siniflara gore ayir

# %% [markdown]
# ## 2. Uygulama Adımları
#
# Aşağıdaki adımlar gösterilebilir:
# 1. Sınıf önceki olasılıklarının hesaplanması
# 2. Her özellik için koşullu olasılıkların / dağılım parametrelerinin bulunması
# 3. Bir gözlem için posterior skorların hesaplanması
# 4. En yüksek olasılığa sahip sınıfın seçilmesi

# %%
# TODO:
# Kendi Naive Bayes uygulamani burada yaz
#
# Ornek basliklar:
# def fit_naive_bayes(X, y):
#     ...
#
# def predict_naive_bayes(X):
#     ...

# %% [markdown]
# ## 3. Değerlendirme
#
# Bu bölümde:
# - doğruluk
# - karmaşıklık matrisi
# - hangi sınıflarda daha çok hata olduğu
# - kütüphane tabanlı sonuç ile karşılaştırma
#
# yer alabilir.
